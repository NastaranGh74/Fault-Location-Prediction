# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
from scipy import stats
pd.set_option('display.max_rows', 200) #number of rows for printing

# %%
from google.colab import files
uploaded = files.upload()       #upload the file to google colab
import io
data = pd.read_excel(io.BytesIO(uploaded['Phasec.xlsx']))      #read the uploaded excel file
data
# Out:
#      <input type="file" id="files-af20a9dd-c695-4959-a161-abebc417b991" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af20a9dd-c695-4959-a161-abebc417b991">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Phasec.xlsx to Phasec (1).xlsx
#        Eva_1     Evb_1     Evc_1  ...     Evc_2  All         class
# 0   0.003840  0.493117  0.503044  ...  0.513800    1  BC_nonground
# 1   0.496941  0.501723  0.001336  ...  0.016595    0  AB_nonground
# 2   0.196144  0.606026  0.197829  ...  0.002484    0            BG
# 3   0.056972  0.404159  0.538869  ...  0.507470    1  BC_nonground
# 4   0.193417  0.201792  0.604791  ...  0.992273    2            CG
# 5   0.008938  0.009758  0.981304  ...  0.605895    2            CG
# 6   0.014673  0.894433  0.090894  ...  0.395372    2            BC
# 7   0.180895  0.184452  0.634653  ...  0.632267    2            CG
# 8   0.625453  0.368836  0.005711  ...  0.121748    0            AB
# 9   0.180070  0.637247  0.182682  ...  0.186030    0            BG
# 10  0.008370  0.983715  0.007915  ...  0.197460    0            BG
# 11  0.983248  0.008130  0.008622  ...  0.197269    0            AG
# 12  0.080313  0.343100  0.576587  ...  0.501805    1  BC_nonground
# 13  0.983557  0.007927  0.008515  ...  0.197295    0            AG
# 14  0.321068  0.574490  0.104442  ...  0.252240    2            BC
# 15  0.187863  0.341135  0.471003  ...  0.072186    2            BC
# 16  0.634837  0.182294  0.182869  ...  0.185067    0            AG
# 17  0.195883  0.605960  0.198157  ...  0.002389    0            BG
# 18  0.010069  0.555666  0.434265  ...  0.415813    0     Transient
# 19  0.180719  0.182974  0.636307  ...  0.631966    2            CG
# 20  0.008113  0.984384  0.007503  ...  0.197968    0            BG
# 21  0.196452  0.605914  0.197634  ...  0.002604    0            BG
# 22  0.008214  0.984105  0.007681  ...  0.197640    0            BG
# 23  0.191552  0.203290  0.605158  ...  0.991940    2            CG
# 24  0.500512  0.168627  0.330860  ...  0.032735    2            AC
# 25  0.448882  0.489593  0.061525  ...  0.000355    0  AB_nonground
# 26  0.179515  0.180817  0.639667  ...  0.632386    0      No Fault
# 27  0.446246  0.037825  0.515929  ...  0.498285    1  AC_nonground
# 28  0.605344  0.196966  0.197691  ...  0.003290    0            AG
# 29  0.651789  0.052713  0.295499  ...  0.339456    2            AC
# 30  0.632636  0.183226  0.184138  ...  0.185577    0            AG
# 31  0.179515  0.180817  0.639667  ...  0.632386    2            CG
# 32  0.501547  0.000816  0.497637  ...  0.506057    1  AC_nonground
# 33  0.486334  0.006801  0.506865  ...  0.499904    1  AC_nonground
# 34  0.983755  0.007781  0.008464  ...  0.197441    0            AG
# 35  0.605440  0.197091  0.197469  ...  0.003257    0            AG
# 36  0.555375  0.417693  0.026932  ...  0.074742    0            AB
# 37  0.497424  0.488002  0.014574  ...  0.005194    0  AB_nonground
# 38  0.441515  0.451381  0.107104  ...  0.006099    0            AB
# 39  0.949568  0.006566  0.043865  ...  0.400750    2            AC
# 40  0.189513  0.205092  0.605395  ...  0.991536    2            CG
# 28  0.884937 -0.493844 -0.416073  2.215799 -1.169434 -1.117887
# 29  1.045595 -1.005862 -0.067349  0.746545 -0.848929  0.087666
# 30  0.979344 -0.542611 -0.464395  0.964163 -0.530666 -0.464170
# 31 -0.588036 -0.551162  1.159753 -0.571696 -0.530854  1.138168
# 32  0.525897 -1.190064  0.653355  0.466295 -1.147882  0.685128
# 33  0.473273 -1.168823  0.686260  0.509795 -1.170724  0.663062
# 34  2.193891 -1.165345 -1.090741  0.880986 -0.487338 -0.421624
# 35  0.885269 -0.493398 -0.416864  2.215351 -1.168861 -1.118004
# 36  0.712091  0.289613 -1.024895  0.559773  0.272103 -0.861645
# 37  0.511636  0.539171 -1.068959  0.505766  0.571677 -1.111057
# 38  0.318242  0.409186 -0.739051  0.897655  0.167953 -1.107813
# 39  2.075637 -1.169655 -0.964523  0.443678 -0.754744  0.307477
# 40 -0.553452 -0.465001  1.037557 -1.189080 -1.161796  2.426147
# 41 -0.582092  1.053836 -0.458592 -0.572000  1.030195 -0.454747
# 42  0.999886 -0.552118 -0.476019  0.969195 -0.531711 -0.468351
# 43 -0.581578  1.043470 -0.448709 -0.575596  1.024278 -0.444957
# 44 -1.178019 -1.157636  2.377073 -0.543068 -0.468163  1.044321
# 45 -1.177932 -1.158762  2.378114 -0.533224 -0.475420  1.041459
# 46  0.885426 -0.493762 -0.416660  2.215654 -1.169187 -1.117987

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier              #we want to try learning through KNN
from sklearn.model_selection import train_test_split  
x_train,x_test,y_train,y_test=train_test_split(x_df,y_df,test_size=0.2,random_state=12)      #split the data to training and testing set



knn=KNeighborsClassifier(n_neighbors=7,metric='minkowski',p=2)                   #first set these parameters and check the performance, we will later fine tune the parameters
knn=knn.fit(x_train,y_train)                       #fit the model to our train data
y_pred = knn.predict(x_test)

# %%
pd.set_option('display.max_rows', 100) #number of rows for printing
print(y_train)
# Out:
# 15    2
# 35    0
# 14    2
# 31    2
# 19    2
# 9     0
# 28    0
# 44    2
# 16    0
# 20    0
# 45    2
# 32    1
# 1     0
# 26    0
# 4     2
# 41    0
# 36    0
# 18    0
# 37    0
# 40    2
# 8     0
# 21    0
# 0     1
# 10    0
# 46    0
# 34    0
# 25    0
# 13    0
# 5     2
# 22    0
# 12    1
# 42    0
# 3     1
# 2     0
# 6     2
# 27    1
# 11    0
# Name: All, dtype: int64

# %%
errors = abs(y_pred - y_test)# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2))
#https://towardsdatascience.com/random-forest-in-python-24d0893d51c0
# Out:
# Mean Absolute Error: 0.7

# %%
print('\n')
# Accuracy on Train
print("The Training Accuracy is: ", knn.score(x_train, y_train))

# Accuracy on Test
print("The Testing Accuracy is: ", knn.score(x_test, y_test))
# Out:
# The Training Accuracy is:  0.8378378378378378
# The Testing Accuracy is:  0.6

# %%
# Confusion Matrix function
#adopted from https://github.com/Pitsillides91/Python-Tutorials/blob/master/Introduction%20to%20ML%20-%20Logistic%20Regression%20Example/Introduction%20to%20Machine%20Learning%20-%20Logistic%20Regression%20Example%20(Complete).ipynb

def plot_confusion_matrix(cm, classes=None, title='Confusion matrix'):
    """Plots a confusion matrix."""
    if classes is not None:
        sns.heatmap(cm, cmap="YlGnBu", xticklabels=classes, yticklabels=classes, vmin=0, vmax=1, annot=True, annot_kws={'size':50})
    else:
        sns.heatmap(cm, vmin=0, vmax=1)
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusion = confusion_matrix(y_test, y_pred)
print('Confusion Matrix\n')
print(confusion)
# Out:
# Confusion Matrix
#
# [[4 0 0]
#  [1 0 0]
#  [3 0 2]]

# %%
y_pred
# Out:
# array([2, 0, 2, 0, 0, 0, 0, 0, 0, 0])

# %%
y_test
# Out:
# 23    2
# 43    0
# 7     2
# 38    0
# 33    1
# 24    2
# 29    2
# 39    2
# 17    0
# 30    0
# Name: All, dtype: int64

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Accuracy: 0.60
#
# Micro Precision: 0.60
# Micro Recall: 0.60
# Micro F1-score: 0.60
#
# Macro Precision: 0.50
# Macro Recall: 0.47
# Macro F1-score: 0.41
#
# Weighted Precision: 0.70
# Weighted Recall: 0.60
# Weighted F1-score: 0.55
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # SVM

# %%
#Support Vector Machine
from sklearn.svm import SVC

svm_classifier = SVC(kernel= 'rbf', gamma='auto') #after some research, we chose rbf
svm_classifier.fit(x_train, y_train)
y_predict_svm = svm_classifier.predict(x_test)

# %%
# Use the predict method on the test data
errors = abs(y_predict_svm - y_test)# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2))
#https://towardsdatascience.com/random-forest-in-python-24d0893d51c0
# Out:
# Mean Absolute Error: 0.6

# %%
print('\n')
# Accuracy on Train
print("The Training Accuracy is: ", svm_classifier.score(x_train, y_train))

# Accuracy on Test
print("The Testing Accuracy is: ", svm_classifier.score(x_test, y_test))
# Out:
# The Training Accuracy is:  0.8648648648648649
# The Testing Accuracy is:  0.7

# %%
y_predict_svm
# Out:
# array([2, 0, 2, 0, 1, 0, 0, 0, 0, 0])

# %%
y_pred=y_predict_svm
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Accuracy: 0.70
#
# Micro Precision: 0.70
# Micro Recall: 0.70
# Micro F1-score: 0.70
#
# Macro Precision: 0.86
# Macro Recall: 0.80
# Macro F1-score: 0.77
#
# Weighted Precision: 0.83
# Weighted Recall: 0.70
# Weighted F1-score: 0.68

# %% [markdown]
# # RF

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

rf_classifier = RandomForestClassifier(max_depth=2, random_state=42)
rf_classifier.fit( x_train, y_train)
y_predict_rf = rf_classifier.predict(x_test)

# %%
errors = abs(y_predict_rf - y_test)# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
#https://towardsdatascience.com/random-forest-in-python-24d0893d51c0
# Out:
# Mean Absolute Error: 0.6 degrees.

# %%
print('\n')
# Accuracy on Train
print("The Training Accuracy is: ", rf_classifier.score(x_train, y_train))

# Accuracy on Test
print("The Testing Accuracy is: ", rf_classifier.score(x_test, y_test))
# Out:
# The Training Accuracy is:  0.918918918918919
# The Testing Accuracy is:  0.7

# %%
y_pred=y_predict_rf
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Accuracy: 0.70
#
# Micro Precision: 0.70
# Micro Recall: 0.70
# Micro F1-score: 0.70
#
# Macro Precision: 0.86
# Macro Recall: 0.80
# Macro F1-score: 0.77
#
# Weighted Precision: 0.83
# Weighted Recall: 0.70
# Weighted F1-score: 0.68

# %% [markdown]
# # DT

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier( max_depth=7)
decision_tree = decision_tree.fit(x_train, y_train)
y_predict_dt = decision_tree.predict(x_test)

# %%
errors = abs(y_predict_dt - y_test)# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2))
#https://towardsdatascience.com/random-forest-in-python-24d0893d51c0
# Out:
# Mean Absolute Error: 0.2

# %%
print('\n')
# Accuracy on Train
print("The Training Accuracy is: ", decision_tree.score(x_train, y_train))

# Accuracy on Test
print("The Testing Accuracy is: ", decision_tree.score(x_test, y_test))
print('\n')
# Out:
# The Training Accuracy is:  0.972972972972973
# The Testing Accuracy is:  0.9

# %%
y_predict_dt
# Out:
# array([2, 0, 2, 0, 1, 0, 2, 2, 0, 0])

# %%
y_pred=y_predict_dt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Accuracy: 0.90
#
# Micro Precision: 0.90
# Micro Recall: 0.90
# Micro F1-score: 0.90
#
# Macro Precision: 0.93
# Macro Recall: 0.93
# Macro F1-score: 0.93
#
# Weighted Precision: 0.92
# Weighted Recall: 0.90
# Weighted F1-score: 0.90

# %%
data
# Out:
#        Eva_1     Evb_1     Evc_1     Eva_2     Evb_2     Evc_2  All
# 0   0.003840  0.493117  0.503044  0.039577  0.446623  0.513800    1
# 1   0.496941  0.501723  0.001336  0.493881  0.489524  0.016595    0
# 2   0.196144  0.606026  0.197829  0.003027  0.994489  0.002484    0
